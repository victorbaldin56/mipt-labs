# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 22})
import math

# %%
name = "g1"
plt.rcParams.update({'font.size': 22})

# %%
data = pd.read_csv(name + ".csv", names=["p", "l"])

# %%
X =  data["l"].values
sigma_X = 0.02
Y = data["p"].values
sigma_Y = 0.002

# %%
A = np.vstack([X, np.ones(len(X))]).T
k, b = np.linalg.lstsq(A, Y, rcond=None)[0]
#sigma_k = math.sqrt((Y.std() - Y.mean()**2 ) / (X.std() - X.mean()**2 ) - b**2 ) / math.sqrt(len(X))
#eps_k = sigma_k / k
#sigma_b = sigma_k * math.sqrt(X.std() / X.mean() - X.mean()**2 )

# %%
fig = plt.figure(figsize=(12, 7))
ax = fig.gca()
plt.scatter(X, Y, marker=".")
delta_x = (X.max() - X.min()) / len(X)
delta_y = (Y.max() - Y.min()) / len(Y)
plt.errorbar(X, Y, xerr=sigma_X, yerr=sigma_Y, linestyle="None")
ax.set_xlim(X.min() - delta_x/2, X.max() + delta_x/2 )
ax.set_ylim((Y.min() - delta_y/2 ), Y.max() + delta_y/2 )
plt.xlabel("$\lambda$, $10^{-7}$ м")
plt.ylabel("$\sin\ φ - \sin \psi$ ")
plt.plot(X, (k*X + b), 'r', label='Fitted line')
plt.grid(True)
plt.savefig(name + ".png")
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\l'
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# <>:9: SyntaxWarning: invalid escape sequence '\l'
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/rv/yhrtt14j28951pqmbr82j5cc0000gn/T/ipykernel_44317/1988224467.py:9: SyntaxWarning: invalid escape sequence '\l'
#   plt.xlabel("$\lambda$, $10^{-7}$ м")
# /var/folders/rv/yhrtt14j28951pqmbr82j5cc0000gn/T/ipykernel_44317/1988224467.py:10: SyntaxWarning: invalid escape sequence '\s'
#   plt.ylabel("$\sin\ φ - \sin \psi$ ")

# %%
k

# %%
b

# %%
data

# %%
print(data2.to_latex())

# %%
data["d"].mean()
